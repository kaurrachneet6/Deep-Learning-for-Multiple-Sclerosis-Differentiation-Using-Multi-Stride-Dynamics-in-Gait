# %% [markdown]
# ## Using multiple strides in treadmill-acquired gait data for Multiple Sclerosis prediction
# ### Extracting raw treadmill features (COPX, COPY, ForceZ and belt speed) for each stride and time normalizing data in a given stride, and so retaining 30 samples per stride after downsampling with smooting approach.
# * Each stride is a 2D data with 30 time steps and 4 features (COPX, COPY, ForceZ and belt speed)
# * Somehow keep track of ordering of strides and if they are consequetive or not since later on we need to retain groups of 5 consequetive strides only for our analysis
# * Keep track of PID, Trial ID (W/WT) and labels for each stride, maybe in a separate .csv file where each csv file for 2D data has a corresponding PID, TrialID and label
# * **Sanity Check to make sure we retained only the same strides as we used for othe domain knowledge features:** Overall, 1654 (HOA: 905, PwMS: 749) and 1576 (HOA: 878, PwMS: 698) strides were retrieved from W and WT trials, respectively, across 35 subjects (HOA: 18, PwMS: 17).

# %%
import numpy as np
import pandas as pd
import math
import os
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = 'C:\\Users\\Rachneet Kaur\\Box\\GAIT\\sample_data\\data_export\\'

# %%
# Get all the file names in the dictionary
control_ids = list(range(200, 220))
ms_ids = list(range(300, 315)) + [318, 320, 321, 322, 323]
raw_controls_t1 = [path +str(i)+ '_B3_TRIAL01_RAWDATA.csv' for i in control_ids]
raw_controls_t2 = [path +str(i)+ '_B3_TRIAL02_RAWDATA.csv' for i in control_ids]

raw_ms_t1 = [path +str(i)+ '_B3_TRIAL01_RAWDATA.csv' for i in ms_ids]
raw_ms_t2 = [path +str(i)+ '_B3_TRIAL02_RAWDATA.csv' for i in ms_ids]

gait_controls_t1 = [path +str(i)+ '_B3_TRIAL01_GAITCYCLES.csv' for i in control_ids]
gait_controls_t2 = [path +str(i)+ '_B3_TRIAL02_GAITCYCLES.csv' for i in control_ids]

gait_ms_t1 = [path +str(i)+ '_B3_TRIAL01_GAITCYCLES.csv' for i in ms_ids]
gait_ms_t2 = [path +str(i)+ '_B3_TRIAL02_GAITCYCLES.csv' for i in ms_ids]

# %%
# for every GaitCycle file, a sequence of walk will always start with a heel strike on the right foot.
# Thus the order of the Gait event points would be HSR, TOL, MidSSR, HSL, TOR and MidSSL.
gait_type = np.array(['HSR', 'TOL', 'MidSSR', 'HSL', 'TOR', 'MidSSL'])

#Delta_time
delta_time = 0.002 #Since the data is collected is 500Hz frequency

# %%
#functions to drop missing values and invalid data 
def drop_unnamed(dataframe):
    return(dataframe.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis = 1))

#Eliminate missing values
def drop_na(dataframe):
    return(pd.DataFrame.dropna(dataframe))

#Eliminate invalid data 
def get_valid(dataframe):
    return(dataframe.loc[dataframe.Valid == True, :])

# Valid strides in the gait_cycles.csv file 
def get_cycle(dataframe):
    stride_start = min(dataframe.loc[dataframe.EventType == 'HSR'].index)
    stride_end = max(dataframe.loc[dataframe.EventType == 'MidSSL'].index)   
    return dataframe.loc[stride_start:stride_end]

# Restore the indexing for the cropped dataframe 
def change_index(dataframe):
    dataframe.index = range(len(dataframe))
    return dataframe

# get all the valid index in order: HSR-TOL-MidSSR-HSL-TOR-MidSSL
def set_complete(data_frame):
    # input is the Dataframe includes ONLY valid points 
    # get all the index of HSR since it starts with heal strike left
    # if the length of last gait cycle contain HSR does not equals to 6, then ignore it
    
    HSR = data_frame.loc[data_frame.EventType == 'HSR'].index
    last_idx = HSR[-1]
    last_all_idx = data_frame.index[-1]
    # if the last gait cycles contains HSR is not a valid gait cycle, then we should consider the last second HSR instead.
    if((last_all_idx-last_idx) < 5):
        HSR = HSR[0:-1] 
    else:
        HSR = HSR
    
    # get all the valid index in order: HSR-TOL-MidSSR-HSL-TOR-MidSSL
    valid = []
    for idx_HSR in HSR:
        if (((idx_HSR + 1) in data_frame.index) & ((idx_HSR + 2) in data_frame.index) &
            ((idx_HSR + 3) in data_frame.index) & ((idx_HSR + 4) in data_frame.index) & 
            ((idx_HSR + 5) in data_frame.index)):
            # the valid index exist in the dataframe.
            if((data_frame.loc[idx_HSR + 1].EventType == 'TOL') & (data_frame.loc[idx_HSR + 2].EventType == 'MidSSR') & 
               (data_frame.loc[idx_HSR + 3].EventType == 'HSL') & (data_frame.loc[idx_HSR + 4].EventType == 'TOR') & 
               (data_frame.loc[idx_HSR + 5].EventType == 'MidSSL')):
                valid.extend(range(idx_HSR, idx_HSR+6))
    #returns the list of valid indices which form complete strides 
    return valid

# %%
#Preprocessing the files to delete missing and invalid data 
#For each person (control and MS) in Trial 1
def cleaning(pid, trial = 1, cohort = 'controls'):
    if (cohort == 'controls'):
        if (trial == 1):
            gait = pd.read_csv(gait_controls_t1[pid])
            raw = pd.read_csv(raw_controls_t1[pid])
        else:
            gait = pd.read_csv(gait_controls_t2[pid])
            raw = pd.read_csv(raw_controls_t2[pid])            
    
    if (cohort == 'pwms'):
        if (trial == 1):
            gait = pd.read_csv(gait_ms_t1[pid])
            raw = pd.read_csv(raw_ms_t1[pid])
        else:
            gait = pd.read_csv(gait_ms_t2[pid])
            raw = pd.read_csv(raw_ms_t2[pid])            
    gait = drop_na(gait)
    gait  = get_valid(gait)

    #Reducing to complete strides data 
    gait = get_cycle(gait)
    indices_complete = set_complete(gait)
    gait = gait.loc[indices_complete]

    #Resetting the index 
    gait = change_index(gait)
    return indices_complete, gait, raw

# %% [markdown]
# ## Creating and saving the raw data for original length strides for PIDs and trials of interest

# %%
path_to_save_original_strides = 'C:\\Users\\Rachneet Kaur\\Box\\GaitLSTMproject\\raw_treadmill_features\\original_strides\\'
features_of_interest = ['Speed', 'TreadMill_FZ', 'COPX', 'COPY']
raw_labels = pd.DataFrame(columns = ['PID', 'TrialID', 'StrideIndex', 'FileName', 'label', 'OriginalStrideLength'])

# %%
#Extracting the original stride's raw data features 
def stride_original_raw_data(index, pid, trial_id, cohort):
    df = pd.DataFrame()
    indices_complete, gait, raw = cleaning(index, trial_id, cohort)
    stride_count = int(gait.shape[0]/6) #6 events in each stride
    if cohort == 'controls':
        label = 0
    else:
        label = 1
    
    #Indices for the in-consequetive gait cycles' and hence strides we will discard/label as NaN
    nan_idx = np.array(indices_complete[::6][1:]) - np.array(indices_complete[::6][:-1])
    #If this difference is not 6, that means the valid strides is not in consequent order, hence, we cannot compute lengths 
    nan_stride_idx = np.where(nan_idx!=6)[0]
    
    #Exact times of HSR
    HSR_times = gait['Time'][gait.EventType == 'HSR']
    #For HSR, calculate the closest times from RAWDATA.csv file 
    HSR_times_raw = [raw['Time'][raw['Time']>HSR_times.iloc[i]].iloc[0] for i in range(stride_count)]

    for idx in range(0, stride_count): #Use for all strides for each person, each trial
        try:
            #Indices in raw data relative to the current stride 
            indices_stride = (raw['Time']>=HSR_times_raw[idx]) & (raw['Time']<HSR_times_raw[idx+1]) #Progression vector 
            original_stride = raw[indices_stride][features_of_interest]
            original_stride = original_stride.reset_index(drop = True)
            original_stride_length = len(raw[indices_stride][features_of_interest])
            original_stride_filename = str(pid) + '_' + str(trial_id) + '_' + str(idx) + '.csv'
            if idx not in nan_stride_idx:
                #Saving the original length strides to csv
                original_stride.to_csv(path_to_save_original_strides + original_stride_filename)
            else:
#                 print ('This is a NaN stride')
                original_stride_filename = np.nan
                original_stride_length = np.nan
            raw_labels.loc[len(raw_labels)] = [pid, trial_id, idx, original_stride_filename, label, original_stride_length]
        except:
            pass

# %%
cohorts = ['controls', 'pwms']
trials = [1, 2]
subjects_to_delete = [212, 213, 309, 310, 311]
for trial_id in trials:
    for cohort in cohorts:
        for index in range(0, 20): #20 people in each cohort and each trial
            if cohort == 'controls':
                pid = control_ids[index]
            else:
                pid = ms_ids[index]
            if pid not in subjects_to_delete:
                stride_original_raw_data(index, pid, trial_id, cohort)

#Saving the log of each stride created in this labels file 
raw_labels.to_csv(path_to_save_original_strides + '..\\original_stride_raw_labels.csv')
print ('No. of PIDs in these raw strides: ', len(raw_labels['PID'].unique()))
# Out:
# No. of PIDs in these raw strides:  35

# %% [markdown]
# ### Downsample with smoothing the original length strides to define fixed shape input tensor for models with raw treadmill features
# * Basically, the downsampled stride's .csv is a windowed mean version (with 30 windows) of the original length stride's .csv.
# * We create a downsampled_labels.csv with columns for cohort (HOA/MS), trial (W/WT), file name (212_W_1_25), PID (212), stride number (23), length of the downsampled stride and label (0 - HOA/1-MS).
# * So the idea is to use this file downsampled_labels.csv to decide the identifiers for the training/testing sets/folds and then pull out the .csvs of the same name as samples and pull the from the label column of the labels.csv the labels of the corresponding identifier strides.

# %%
#Path for downsampled strides (each file has 30 downsampled/smoothed frames and 4 features)
path_to_save_downsampled_strides = 'C:\\Users\\Rachneet Kaur\\Box\\GaitLSTMproject\\raw_treadmill_features\\downsampled_strides\\'

#Keeping 30 stride-normalized time steps for each stride while downsampling
downsampled_steps_per_stride = 30

#Dataframe to keep track of all the downsampled strides
downsampled_labels = raw_labels
downsampled_labels['DownsampledStrideLength'] = downsampled_steps_per_stride

# %%
#Use mean with disjoint windows to downsample while smoothing 
original_strides = os.listdir(path_to_save_original_strides)
print ('No. of original strides = ', len(original_strides))
for original_stride in original_strides:
    print ('Currently processing ', original_stride)
    original_stride_df = pd.read_csv(path_to_save_original_strides+original_stride, index_col = 0)  
#     print (original_stride_df)
    #Creating the downsampled stride with 30 time steps for each stride containg n time steps 
    downsampled_stride = pd.DataFrame(columns = original_stride_df.columns) 
    #Creating an approximately even splits of frames to divide n time steps in a stride to 30 
    #downsampled time steps
    splits = np.array_split(original_stride_df.index, downsampled_steps_per_stride)
    for split in splits:
        #We do the windowed mean of each split of frames to get the downsampled frame
        downsampled_stride.loc[len(downsampled_stride)] = original_stride_df.loc[split].mean()
#     print (downsampled_stride)
    #Saving the downsampled stride with 30*4 with the unique key in the name
    downsampled_stride.to_csv(path_to_save_downsampled_strides+original_stride)
#Saving the log of each stride created in this labels file 
downsampled_labels.to_csv(path_to_save_downsampled_strides + '..\\downsampled_stride_raw_labels.csv')
# Out:
# No. of original strides =  3393
# Currently processing  200_1_0.csv
# Currently processing  200_1_1.csv
# Currently processing  200_1_10.csv
# Currently processing  200_1_11.csv
# Currently processing  200_1_12.csv
# Currently processing  200_1_13.csv
# Currently processing  200_1_14.csv
# Currently processing  200_1_15.csv
# Currently processing  200_1_16.csv
# Currently processing  200_1_17.csv
# Currently processing  200_1_18.csv
# Currently processing  200_1_19.csv
# Currently processing  200_1_2.csv
# Currently processing  200_1_20.csv
# Currently processing  200_1_21.csv
# Currently processing  200_1_22.csv
# Currently processing  200_1_23.csv
# Currently processing  200_1_24.csv
# Currently processing  200_1_25.csv
# Currently processing  200_1_26.csv
# Currently processing  200_1_27.csv
# Currently processing  200_1_28.csv
# Currently processing  200_1_29.csv
# Currently processing  200_1_3.csv
# Currently processing  200_1_30.csv
# Currently processing  200_1_31.csv
# Currently processing  200_1_32.csv
# Currently processing  200_1_33.csv
# Currently processing  200_1_34.csv
# Currently processing  200_1_35.csv
# Currently processing  200_1_36.csv
# Currently processing  200_1_37.csv
# Currently processing  200_1_38.csv
# Currently processing  200_1_39.csv
# Currently processing  200_1_4.csv
# Currently processing  200_1_40.csv
# Currently processing  200_1_41.csv
# Currently processing  200_1_42.csv
# Currently processing  200_1_43.csv
# Currently processing  200_1_5.csv
# Currently processing  200_1_6.csv
# Currently processing  200_1_7.csv
# Currently processing  200_1_8.csv
# Currently processing  200_1_9.csv
# Currently processing  200_2_0.csv
# Currently processing  200_2_1.csv
# Currently processing  200_2_10.csv
# Currently processing  200_2_11.csv
# Currently processing  200_2_12.csv
# Currently processing  200_2_13.csv
# Currently processing  200_2_14.csv
# Currently processing  200_2_15.csv
# Currently processing  200_2_16.csv
# Currently processing  200_2_17.csv
# Currently processing  200_2_18.csv
# Currently processing  200_2_19.csv
# Currently processing  200_2_2.csv
# Currently processing  200_2_20.csv
# Currently processing  200_2_21.csv
# Currently processing  200_2_22.csv
# Currently processing  200_2_23.csv
# Currently processing  200_2_24.csv
# Currently processing  200_2_25.csv
# Currently processing  200_2_26.csv
# Currently processing  200_2_27.csv
# Currently processing  200_2_28.csv
# Currently processing  200_2_29.csv
# Currently processing  200_2_3.csv
# Currently processing  200_2_30.csv
# Currently processing  200_2_31.csv
# Currently processing  200_2_32.csv
# Currently processing  200_2_33.csv
# Currently processing  200_2_34.csv
# Currently processing  200_2_35.csv
# Currently processing  200_2_36.csv
# Currently processing  200_2_37.csv
# Currently processing  200_2_38.csv
# Currently processing  200_2_39.csv
# Currently processing  200_2_4.csv
# Currently processing  200_2_40.csv
# Currently processing  200_2_41.csv
# Currently processing  200_2_42.csv
# Currently processing  200_2_43.csv
# Currently processing  200_2_44.csv
# Currently processing  200_2_45.csv
# Currently processing  200_2_46.csv
# Currently processing  200_2_5.csv
# Currently processing  200_2_6.csv
# Currently processing  200_2_7.csv
# Currently processing  200_2_8.csv
# Currently processing  200_2_9.csv
# Currently processing  201_1_0.csv
# Currently processing  201_1_1.csv
# Currently processing  201_1_10.csv
# Currently processing  201_1_11.csv
# Currently processing  201_1_12.csv
# Currently processing  201_1_13.csv
# Currently processing  201_1_14.csv
# Currently processing  201_1_15.csv
# Currently processing  201_1_16.csv
# Currently processing  201_1_17.csv
# Currently processing  201_1_18.csv
# Currently processing  201_1_19.csv
# Currently processing  201_1_2.csv
# Currently processing  201_1_20.csv
# Currently processing  201_1_21.csv
# Currently processing  201_1_22.csv
# Currently processing  201_1_23.csv
# Currently processing  201_1_24.csv
# Currently processing  201_1_25.csv
# Currently processing  201_1_26.csv
# Currently processing  201_1_27.csv
# Currently processing  201_1_28.csv
# Currently processing  201_1_29.csv
# Currently processing  201_1_3.csv
# Currently processing  201_1_30.csv
# Currently processing  201_1_31.csv
# Currently processing  201_1_32.csv
# Currently processing  201_1_33.csv
# Currently processing  201_1_34.csv
# Currently processing  201_1_35.csv
# Currently processing  201_1_36.csv
# Currently processing  201_1_37.csv
# Currently processing  201_1_38.csv
# Currently processing  201_1_39.csv
# Currently processing  201_1_4.csv
# Currently processing  201_1_5.csv
# Currently processing  201_1_6.csv
# Currently processing  201_1_7.csv
# Currently processing  201_1_8.csv
# Currently processing  201_1_9.csv
# Currently processing  201_2_0.csv
# Currently processing  201_2_1.csv
# Currently processing  201_2_10.csv
# Currently processing  201_2_11.csv
# Currently processing  201_2_12.csv
# Currently processing  201_2_13.csv
# Currently processing  201_2_14.csv
# Currently processing  201_2_15.csv
# Currently processing  201_2_16.csv
# Currently processing  201_2_17.csv
# Currently processing  201_2_18.csv
# Currently processing  201_2_19.csv
# Currently processing  201_2_20.csv
# Currently processing  201_2_21.csv
# Currently processing  201_2_22.csv
# Currently processing  201_2_23.csv
# Currently processing  201_2_24.csv
# Currently processing  201_2_25.csv
# Currently processing  201_2_26.csv
# Currently processing  201_2_27.csv
# Currently processing  201_2_28.csv
# Currently processing  201_2_29.csv
# Currently processing  201_2_3.csv
# Currently processing  201_2_30.csv
# Currently processing  201_2_31.csv
# Currently processing  201_2_32.csv
# Currently processing  201_2_33.csv
# Currently processing  201_2_34.csv
# Currently processing  201_2_35.csv
# Currently processing  201_2_36.csv
# Currently processing  201_2_37.csv
# Currently processing  201_2_4.csv
# Currently processing  201_2_5.csv
# Currently processing  201_2_6.csv
# Currently processing  201_2_7.csv
# Currently processing  201_2_8.csv
# Currently processing  201_2_9.csv
# Currently processing  202_1_0.csv
# Currently processing  202_1_1.csv
# Currently processing  202_1_10.csv
# Currently processing  202_1_11.csv
# Currently processing  202_1_12.csv
# Currently processing  202_1_13.csv
# Currently processing  202_1_14.csv
# Currently processing  202_1_15.csv
# Currently processing  202_1_16.csv
# Currently processing  202_1_17.csv
# Currently processing  202_1_18.csv
# Currently processing  202_1_19.csv
# Currently processing  202_1_2.csv
# Currently processing  202_1_20.csv
# Currently processing  202_1_21.csv
# Currently processing  202_1_22.csv
# Currently processing  202_1_23.csv
# Currently processing  202_1_24.csv
# Currently processing  202_1_25.csv
# Currently processing  202_1_26.csv
# Currently processing  202_1_27.csv
# Currently processing  202_1_28.csv
# Currently processing  202_1_29.csv
# Currently processing  202_1_3.csv
# Currently processing  202_1_30.csv
# Currently processing  202_1_31.csv
# Currently processing  202_1_32.csv
# Currently processing  202_1_33.csv
# Currently processing  202_1_34.csv
# Currently processing  202_1_35.csv
# Currently processing  202_1_36.csv
# Currently processing  202_1_37.csv
# Currently processing  202_1_38.csv
# Currently processing  202_1_39.csv
# Currently processing  202_1_4.csv
# Currently processing  202_1_40.csv
# Currently processing  202_1_41.csv
# Currently processing  202_1_42.csv
# Currently processing  202_1_43.csv
# Currently processing  202_1_44.csv
# Currently processing  202_1_45.csv
# Currently processing  202_1_5.csv
# Currently processing  202_1_6.csv
# Currently processing  202_1_7.csv
# Currently processing  202_1_8.csv
# Currently processing  202_1_9.csv
# Currently processing  202_2_0.csv
# Currently processing  202_2_1.csv
# Currently processing  202_2_10.csv
# Currently processing  202_2_11.csv
# Currently processing  202_2_12.csv
# Currently processing  202_2_13.csv
# Currently processing  202_2_14.csv
# Currently processing  202_2_15.csv
# Currently processing  202_2_16.csv
# Currently processing  202_2_17.csv
# Currently processing  202_2_18.csv
# Currently processing  202_2_19.csv
# Currently processing  202_2_2.csv
# Currently processing  202_2_20.csv
# Currently processing  202_2_21.csv
# Currently processing  202_2_22.csv
# Currently processing  202_2_23.csv
# Currently processing  202_2_24.csv
# Currently processing  202_2_25.csv
# Currently processing  202_2_26.csv
# Currently processing  202_2_27.csv
# Currently processing  202_2_28.csv
# Currently processing  202_2_29.csv
# Currently processing  202_2_3.csv
# Currently processing  202_2_30.csv
# Currently processing  202_2_31.csv
# Currently processing  202_2_32.csv
# Currently processing  202_2_33.csv
# Currently processing  202_2_34.csv
# Currently processing  202_2_35.csv
# Currently processing  202_2_36.csv
# Currently processing  202_2_37.csv
# Currently processing  202_2_4.csv
# Currently processing  202_2_5.csv
# Currently processing  202_2_6.csv
# Currently processing  202_2_7.csv
# Currently processing  202_2_8.csv
# Currently processing  202_2_9.csv
# Currently processing  203_1_0.csv
# Currently processing  203_1_1.csv
# Currently processing  203_1_10.csv
# Currently processing  203_1_11.csv
# Currently processing  203_1_12.csv
# Currently processing  203_1_13.csv
# Currently processing  203_1_14.csv
# Currently processing  203_1_15.csv
# Currently processing  203_1_16.csv
# Currently processing  203_1_17.csv
# Currently processing  203_1_18.csv
# Currently processing  203_1_19.csv
# Currently processing  203_1_2.csv
# Currently processing  203_1_20.csv
# Currently processing  203_1_21.csv
# Currently processing  203_1_22.csv
# Currently processing  203_1_23.csv
# Currently processing  203_1_24.csv
# Currently processing  203_1_25.csv
# Currently processing  203_1_26.csv
# Currently processing  203_1_27.csv
# Currently processing  203_1_28.csv
# Currently processing  203_1_29.csv
# Currently processing  203_1_3.csv
# Currently processing  203_1_30.csv
# Currently processing  203_1_31.csv
# Currently processing  203_1_32.csv
# Currently processing  203_1_33.csv
# Currently processing  203_1_34.csv
# Currently processing  203_1_35.csv
# Currently processing  203_1_36.csv
# Currently processing  203_1_37.csv
# Currently processing  203_1_38.csv
# Currently processing  203_1_39.csv
# Currently processing  203_1_4.csv
# Currently processing  203_1_40.csv
# Currently processing  203_1_41.csv
# Currently processing  203_1_42.csv
# Currently processing  203_1_43.csv
# Currently processing  203_1_44.csv
# Currently processing  203_1_5.csv
# Currently processing  203_1_7.csv
# Currently processing  203_1_8.csv
# Currently processing  203_1_9.csv
# Currently processing  203_2_0.csv
# Currently processing  203_2_1.csv
# Currently processing  203_2_10.csv
# Currently processing  203_2_11.csv
# Currently processing  203_2_12.csv
# Currently processing  203_2_13.csv
# Currently processing  203_2_14.csv
# Currently processing  203_2_15.csv
# Currently processing  203_2_16.csv
# Currently processing  203_2_17.csv
# Currently processing  203_2_18.csv
# Currently processing  203_2_19.csv
# Currently processing  203_2_2.csv
# Currently processing  203_2_20.csv
# Currently processing  203_2_21.csv
# Currently processing  203_2_22.csv
# Currently processing  203_2_23.csv
# Currently processing  203_2_24.csv
# Currently processing  203_2_25.csv
# Currently processing  203_2_26.csv
# Currently processing  203_2_27.csv
# Currently processing  203_2_28.csv
# Currently processing  203_2_29.csv
# Currently processing  203_2_3.csv
# Currently processing  203_2_30.csv
# Currently processing  203_2_31.csv
# Currently processing  203_2_32.csv
# Currently processing  203_2_33.csv
# Currently processing  203_2_34.csv
# Currently processing  203_2_35.csv
# Currently processing  203_2_36.csv
# Currently processing  203_2_37.csv
# Currently processing  203_2_38.csv
# Currently processing  203_2_39.csv
# Currently processing  203_2_4.csv
# Currently processing  203_2_40.csv
# Currently processing  203_2_41.csv
# Currently processing  203_2_42.csv
# Currently processing  203_2_43.csv
# Currently processing  203_2_44.csv
# Currently processing  203_2_45.csv
# Currently processing  203_2_5.csv
# Currently processing  203_2_6.csv
# Currently processing  203_2_7.csv
# Currently processing  203_2_8.csv
# Currently processing  203_2_9.csv
# Currently processing  204_1_1.csv
# Currently processing  204_1_10.csv
# Currently processing  204_1_11.csv
# Currently processing  204_1_12.csv
# Currently processing  204_1_13.csv
# Currently processing  204_1_14.csv
# Currently processing  204_1_15.csv
# Currently processing  204_1_16.csv
# Currently processing  204_1_17.csv
# Currently processing  204_1_18.csv
# Currently processing  204_1_19.csv
# Currently processing  204_1_2.csv
# Currently processing  204_1_20.csv
# Currently processing  204_1_21.csv
# Currently processing  204_1_22.csv
# Currently processing  204_1_23.csv
# Currently processing  204_1_24.csv
# Currently processing  204_1_25.csv
# Currently processing  204_1_26.csv
# Currently processing  204_1_27.csv
# Currently processing  204_1_28.csv
# Currently processing  204_1_29.csv
# Currently processing  204_1_3.csv
# Currently processing  204_1_30.csv
# Currently processing  204_1_31.csv
# Currently processing  204_1_32.csv
# Currently processing  204_1_33.csv
# Currently processing  204_1_34.csv
# Currently processing  204_1_35.csv
# Currently processing  204_1_36.csv
# Currently processing  204_1_37.csv
# Currently processing  204_1_38.csv
# Currently processing  204_1_39.csv
# Currently processing  204_1_4.csv
# Currently processing  204_1_40.csv
# Currently processing  204_1_41.csv
# Currently processing  204_1_42.csv
# Currently processing  204_1_43.csv
# Currently processing  204_1_44.csv
# Currently processing  204_1_45.csv
# Currently processing  204_1_46.csv
# Currently processing  204_1_47.csv
# Currently processing  204_1_48.csv
# Currently processing  204_1_49.csv
# Currently processing  204_1_5.csv
# Currently processing  204_1_50.csv
# Currently processing  204_1_51.csv
# Currently processing  204_1_52.csv
# Currently processing  204_1_53.csv
# Currently processing  204_1_54.csv
# Currently processing  204_1_55.csv
# Currently processing  204_1_6.csv
# Currently processing  204_1_7.csv
# Currently processing  204_1_8.csv
# Currently processing  204_1_9.csv
# Currently processing  204_2_0.csv
# Currently processing  204_2_1.csv
# Currently processing  204_2_10.csv
# Currently processing  204_2_11.csv
# Currently processing  204_2_12.csv
# Currently processing  204_2_13.csv
# Currently processing  204_2_14.csv
# Currently processing  204_2_15.csv
# Currently processing  204_2_16.csv
# Currently processing  204_2_17.csv
# Currently processing  204_2_18.csv
# Currently processing  204_2_19.csv
# Currently processing  204_2_2.csv
# Currently processing  204_2_20.csv
# Currently processing  204_2_21.csv
# Currently processing  204_2_22.csv
# Currently processing  204_2_23.csv
# Currently processing  204_2_24.csv
# Currently processing  204_2_25.csv
# Currently processing  204_2_26.csv
# Currently processing  204_2_27.csv
# Currently processing  204_2_28.csv
# Currently processing  204_2_29.csv
# Currently processing  204_2_3.csv
# Currently processing  204_2_30.csv
# Currently processing  204_2_31.csv
# Currently processing  204_2_32.csv
# Currently processing  204_2_33.csv
# Currently processing  204_2_34.csv
# Currently processing  204_2_35.csv
# Currently processing  204_2_36.csv
# Currently processing  204_2_37.csv
# Currently processing  204_2_38.csv
# Currently processing  204_2_39.csv
# Currently processing  204_2_4.csv
# Currently processing  204_2_40.csv
# Currently processing  204_2_41.csv
# Currently processing  204_2_42.csv
# Currently processing  204_2_43.csv
# Currently processing  204_2_44.csv
# Currently processing  204_2_45.csv
# Currently processing  204_2_46.csv
# Currently processing  204_2_47.csv
# Currently processing  204_2_48.csv
# Currently processing  204_2_49.csv
# Currently processing  204_2_5.csv
# Currently processing  204_2_50.csv
# Currently processing  204_2_51.csv
# Currently processing  204_2_52.csv
# Currently processing  204_2_53.csv
# Currently processing  204_2_54.csv
# Currently processing  204_2_55.csv
# Currently processing  204_2_56.csv
# Currently processing  204_2_57.csv
# Currently processing  204_2_6.csv
# Currently processing  204_2_7.csv
# Currently processing  204_2_8.csv
# Currently processing  204_2_9.csv
# Currently processing  205_1_1.csv
# Currently processing  205_1_10.csv
# Currently processing  205_1_11.csv
# Currently processing  205_1_12.csv
# Currently processing  205_1_13.csv
# Currently processing  205_1_14.csv
# Currently processing  205_1_15.csv
# Currently processing  205_1_16.csv
# Currently processing  205_1_17.csv
# Currently processing  205_1_18.csv
# Currently processing  205_1_19.csv
# Currently processing  205_1_2.csv
# Currently processing  205_1_20.csv
# Currently processing  205_1_21.csv
# Currently processing  205_1_22.csv
# Currently processing  205_1_23.csv
# Currently processing  205_1_24.csv
# Currently processing  205_1_25.csv
# Currently processing  205_1_26.csv
# Currently processing  205_1_27.csv
# Currently processing  205_1_28.csv
# Currently processing  205_1_29.csv
# Currently processing  205_1_3.csv
# Currently processing  205_1_30.csv
# Currently processing  205_1_31.csv
# Currently processing  205_1_32.csv
# Currently processing  205_1_33.csv
# Currently processing  205_1_34.csv
# Currently processing  205_1_35.csv
# Currently processing  205_1_36.csv
# Currently processing  205_1_37.csv
# Currently processing  205_1_38.csv
# Currently processing  205_1_39.csv
# Currently processing  205_1_4.csv
# Currently processing  205_1_40.csv
# Currently processing  205_1_41.csv
# Currently processing  205_1_42.csv
# Currently processing  205_1_43.csv
# Currently processing  205_1_44.csv
# Currently processing  205_1_45.csv
# Currently processing  205_1_46.csv
# Currently processing  205_1_47.csv
# Currently processing  205_1_48.csv
# Currently processing  205_1_49.csv
# Currently processing  205_1_5.csv
# Currently processing  205_1_50.csv
# Currently processing  205_1_51.csv
# Currently processing  205_1_52.csv
# Currently processing  205_1_53.csv
# Currently processing  205_1_54.csv
# Currently processing  205_1_55.csv
# Currently processing  205_1_56.csv
# Currently processing  205_1_6.csv
# Currently processing  205_1_7.csv
# Currently processing  205_1_8.csv
# Currently processing  205_1_9.csv
# Currently processing  205_2_0.csv
# Currently processing  205_2_1.csv
# Currently processing  205_2_10.csv
# Currently processing  205_2_11.csv
# Currently processing  205_2_12.csv
# Currently processing  205_2_13.csv
# Currently processing  205_2_14.csv
# Currently processing  205_2_15.csv
# Currently processing  205_2_16.csv
# Currently processing  205_2_17.csv
# Currently processing  205_2_18.csv
# Currently processing  205_2_19.csv
# Currently processing  205_2_2.csv
# Currently processing  205_2_20.csv
# Currently processing  205_2_21.csv
# Currently processing  205_2_22.csv
# Currently processing  205_2_23.csv
# Currently processing  205_2_24.csv
# Currently processing  205_2_25.csv
# Currently processing  205_2_26.csv
# Currently processing  205_2_27.csv
# Currently processing  205_2_28.csv
# Currently processing  205_2_29.csv
# Currently processing  205_2_3.csv
# Currently processing  205_2_30.csv
# Currently processing  205_2_31.csv
# Currently processing  205_2_32.csv
# Currently processing  205_2_33.csv
# Currently processing  205_2_34.csv
# Currently processing  205_2_35.csv
# Currently processing  205_2_36.csv
# Currently processing  205_2_37.csv
# Currently processing  205_2_38.csv
# Currently processing  205_2_39.csv
# Currently processing  205_2_4.csv
# Currently processing  205_2_40.csv
# Currently processing  205_2_41.csv
# Currently processing  205_2_42.csv
# Currently processing  205_2_43.csv
# Currently processing  205_2_44.csv
# Currently processing  205_2_45.csv
# Currently processing  205_2_46.csv
# Currently processing  205_2_47.csv
# Currently processing  205_2_48.csv
# Currently processing  205_2_49.csv
# Currently processing  205_2_5.csv
# Currently processing  205_2_50.csv
# Currently processing  205_2_51.csv
# Currently processing  205_2_52.csv
# Currently processing  205_2_53.csv
# Currently processing  205_2_54.csv
# Currently processing  205_2_55.csv
# Currently processing  205_2_56.csv
# Currently processing  205_2_57.csv
# Currently processing  205_2_6.csv
# Currently processing  205_2_7.csv
# Currently processing  205_2_8.csv
# Currently processing  205_2_9.csv
# Currently processing  206_1_0.csv
# Currently processing  206_1_1.csv
# Currently processing  206_1_10.csv
# Currently processing  206_1_11.csv
# Currently processing  206_1_12.csv
# Currently processing  206_1_13.csv
# Currently processing  206_1_14.csv
# Currently processing  206_1_15.csv
# Currently processing  206_1_16.csv
# Currently processing  206_1_17.csv
# Currently processing  206_1_18.csv
# Currently processing  206_1_19.csv
# Currently processing  206_1_2.csv
# Currently processing  206_1_20.csv
# Currently processing  206_1_21.csv
# Currently processing  206_1_22.csv
# Currently processing  206_1_23.csv
# Currently processing  206_1_24.csv
# Currently processing  206_1_25.csv
# Currently processing  206_1_26.csv
# Currently processing  206_1_27.csv
# Currently processing  206_1_28.csv
# Currently processing  206_1_29.csv
# Currently processing  206_1_3.csv
# Currently processing  206_1_30.csv
# Currently processing  206_1_31.csv
# Currently processing  206_1_32.csv
# Currently processing  206_1_33.csv
# Currently processing  206_1_34.csv
# Currently processing  206_1_35.csv
# Currently processing  206_1_36.csv
# Currently processing  206_1_37.csv
# Currently processing  206_1_38.csv
# Currently processing  206_1_39.csv
# Currently processing  206_1_4.csv
# Currently processing  206_1_40.csv
# Currently processing  206_1_41.csv
# Currently processing  206_1_42.csv
# Currently processing  206_1_43.csv
# Currently processing  206_1_44.csv
# Currently processing  206_1_45.csv
# Currently processing  206_1_46.csv
# Currently processing  206_1_47.csv
# Currently processing  206_1_48.csv
# Currently processing  206_1_5.csv
# Currently processing  206_1_6.csv
# Currently processing  206_1_7.csv
# Currently processing  206_1_8.csv
# Currently processing  206_1_9.csv
# Currently processing  206_2_0.csv
# Currently processing  206_2_1.csv
# Currently processing  206_2_10.csv
# Currently processing  206_2_11.csv
# Currently processing  206_2_12.csv
# Currently processing  206_2_13.csv
# Currently processing  206_2_14.csv
# Currently processing  206_2_15.csv
# Currently processing  206_2_16.csv
# Currently processing  206_2_17.csv
# Currently processing  206_2_18.csv
# Currently processing  206_2_19.csv
# Currently processing  206_2_2.csv
# Currently processing  206_2_20.csv
# Currently processing  206_2_21.csv
# Currently processing  206_2_22.csv
# Currently processing  206_2_23.csv
# Currently processing  206_2_24.csv
# Currently processing  206_2_25.csv
# Currently processing  206_2_26.csv
# Currently processing  206_2_27.csv
# Currently processing  206_2_28.csv
# Currently processing  206_2_29.csv
# Currently processing  206_2_3.csv
# Currently processing  206_2_30.csv
# Currently processing  206_2_31.csv
# Currently processing  206_2_32.csv
# Currently processing  206_2_33.csv
# Currently processing  206_2_34.csv
# Currently processing  206_2_35.csv
# Currently processing  206_2_36.csv
# Currently processing  206_2_37.csv
# Currently processing  206_2_38.csv
# Currently processing  206_2_39.csv
# Currently processing  206_2_4.csv
# Currently processing  206_2_40.csv
# Currently processing  206_2_41.csv
# Currently processing  206_2_42.csv
# Currently processing  206_2_43.csv
# Currently processing  206_2_44.csv
# Currently processing  206_2_45.csv
# Currently processing  206_2_46.csv
# Currently processing  206_2_47.csv
# Currently processing  206_2_48.csv
# Currently processing  206_2_49.csv
# Currently processing  206_2_5.csv
# Currently processing  206_2_50.csv
# Currently processing  206_2_51.csv
# Currently processing  206_2_52.csv
# Currently processing  206_2_6.csv
# Currently processing  206_2_7.csv
# Currently processing  206_2_8.csv
# Currently processing  206_2_9.csv
# Currently processing  207_1_0.csv
# Currently processing  207_1_1.csv
# Currently processing  207_1_10.csv
# Currently processing  207_1_11.csv
# Currently processing  207_1_12.csv
# Currently processing  207_1_13.csv
# Currently processing  207_1_14.csv
# Currently processing  207_1_15.csv
# Currently processing  207_1_16.csv
# Currently processing  207_1_17.csv
# Currently processing  207_1_18.csv
# Currently processing  207_1_19.csv
# Currently processing  207_1_2.csv
# Currently processing  207_1_20.csv
# Currently processing  207_1_21.csv
# Currently processing  207_1_22.csv
# Currently processing  207_1_23.csv
# Currently processing  207_1_24.csv
# Currently processing  207_1_25.csv
# Currently processing  207_1_26.csv
# Currently processing  207_1_27.csv
# Currently processing  207_1_28.csv
# Currently processing  207_1_29.csv
# Currently processing  207_1_3.csv
# Currently processing  207_1_30.csv
# Currently processing  207_1_31.csv
# Currently processing  207_1_32.csv
# Currently processing  207_1_33.csv
# Currently processing  207_1_34.csv
# Currently processing  207_1_35.csv
# Currently processing  207_1_36.csv
# Currently processing  207_1_37.csv
# Currently processing  207_1_38.csv
# Currently processing  207_1_39.csv
# Currently processing  207_1_4.csv
# Currently processing  207_1_40.csv
# Currently processing  207_1_41.csv
# Currently processing  207_1_42.csv
# Currently processing  207_1_43.csv
# Currently processing  207_1_44.csv
# Currently processing  207_1_45.csv
# Currently processing  207_1_46.csv
# Currently processing  207_1_47.csv
# Currently processing  207_1_48.csv
# Currently processing  207_1_49.csv
# Currently processing  207_1_5.csv
# Currently processing  207_1_50.csv
# Currently processing  207_1_51.csv
# Currently processing  207_1_6.csv
# Currently processing  207_1_7.csv
# Currently processing  207_1_8.csv
# Currently processing  207_1_9.csv
# Currently processing  207_2_0.csv
# Currently processing  207_2_1.csv
# Currently processing  207_2_10.csv
# Currently processing  207_2_11.csv
# Currently processing  207_2_12.csv
# Currently processing  207_2_13.csv
# Currently processing  207_2_14.csv
# Currently processing  207_2_15.csv
# Currently processing  207_2_16.csv
# Currently processing  207_2_17.csv
# Currently processing  207_2_18.csv
# Currently processing  207_2_19.csv
# Currently processing  207_2_2.csv
# Currently processing  207_2_20.csv
# Currently processing  207_2_21.csv
# Currently processing  207_2_22.csv
# Currently processing  207_2_23.csv
# Currently processing  207_2_24.csv
# Currently processing  207_2_25.csv
# Currently processing  207_2_26.csv
# Currently processing  207_2_27.csv
# Currently processing  207_2_28.csv
# Currently processing  207_2_29.csv
# Currently processing  207_2_3.csv
# Currently processing  207_2_30.csv
# Currently processing  207_2_31.csv
# Currently processing  207_2_32.csv
# Currently processing  207_2_33.csv
# Currently processing  207_2_34.csv
# Currently processing  207_2_35.csv
# Currently processing  207_2_36.csv
# Currently processing  207_2_37.csv
# Currently processing  207_2_38.csv
# Currently processing  207_2_39.csv
# Currently processing  207_2_4.csv
# Currently processing  207_2_40.csv
# Currently processing  207_2_41.csv
# Currently processing  207_2_42.csv
# Currently processing  207_2_43.csv
# Currently processing  207_2_44.csv
# Currently processing  207_2_45.csv
# Currently processing  207_2_46.csv
# Currently processing  207_2_47.csv
# Currently processing  207_2_48.csv
# Currently processing  207_2_49.csv
# Currently processing  207_2_5.csv
# Currently processing  207_2_50.csv
# Currently processing  207_2_51.csv
# Currently processing  207_2_52.csv
# Currently processing  207_2_53.csv
# Currently processing  207_2_6.csv
# Currently processing  207_2_7.csv
# Currently processing  207_2_8.csv
# Currently processing  207_2_9.csv
# Currently processing  208_1_0.csv
# Currently processing  208_1_1.csv
# Currently processing  208_1_10.csv
# Currently processing  208_1_11.csv
# Currently processing  208_1_12.csv
# Currently processing  208_1_13.csv
# Currently processing  208_1_14.csv
# Currently processing  208_1_15.csv
# Currently processing  208_1_16.csv
# Currently processing  208_1_17.csv
# Currently processing  208_1_18.csv
# Currently processing  208_1_19.csv
# Currently processing  208_1_2.csv
# Currently processing  208_1_20.csv
# Currently processing  208_1_21.csv
# Currently processing  208_1_22.csv
# Currently processing  208_1_23.csv
# Currently processing  208_1_24.csv
# Currently processing  208_1_25.csv
# Currently processing  208_1_26.csv
# Currently processing  208_1_27.csv
# Currently processing  208_1_28.csv
# Currently processing  208_1_29.csv
# Currently processing  208_1_3.csv
# Currently processing  208_1_30.csv
# Currently processing  208_1_31.csv
# Currently processing  208_1_32.csv
# Currently processing  208_1_33.csv
# Currently processing  208_1_34.csv
# Currently processing  208_1_35.csv
# Currently processing  208_1_36.csv
# Currently processing  208_1_37.csv
# Currently processing  208_1_38.csv
# Currently processing  208_1_39.csv
# Currently processing  208_1_4.csv
# Currently processing  208_1_40.csv
# Currently processing  208_1_41.csv
# Currently processing  208_1_42.csv
# Currently processing  208_1_43.csv
# Currently processing  208_1_44.csv
# Currently processing  208_1_45.csv
# Currently processing  208_1_46.csv
# Currently processing  208_1_47.csv
# Currently processing  208_1_48.csv
# Currently processing  208_1_49.csv
# Currently processing  208_1_5.csv
# Currently processing  208_1_6.csv
# Currently processing  208_1_7.csv
# Currently processing  208_1_8.csv
# Currently processing  208_1_9.csv
# Currently processing  208_2_0.csv
# Currently processing  208_2_1.csv
# Currently processing  208_2_10.csv
# Currently processing  208_2_11.csv
# Currently processing  208_2_12.csv
# Currently processing  208_2_13.csv
# Currently processing  208_2_14.csv
# Currently processing  208_2_15.csv
# Currently processing  208_2_16.csv
# Currently processing  208_2_17.csv
# Currently processing  208_2_18.csv
# Currently processing  208_2_19.csv
# Currently processing  208_2_2.csv
# Currently processing  208_2_20.csv
# Currently processing  208_2_21.csv
# Currently processing  208_2_22.csv
# Currently processing  208_2_23.csv
# Currently processing  208_2_24.csv
# Currently processing  208_2_25.csv
# Currently processing  208_2_26.csv
# Currently processing  208_2_27.csv
# Currently processing  208_2_28.csv
# Currently processing  208_2_29.csv
# Currently processing  208_2_3.csv
# Currently processing  208_2_30.csv
# Currently processing  208_2_31.csv
# Currently processing  208_2_32.csv
# Currently processing  208_2_33.csv
# Currently processing  208_2_34.csv
# Currently processing  208_2_35.csv
# Currently processing  208_2_36.csv
# Currently processing  208_2_37.csv
# Currently processing  208_2_38.csv
# Currently processing  208_2_39.csv
# Currently processing  208_2_4.csv
# Currently processing  208_2_40.csv
# Currently processing  208_2_41.csv
# Currently processing  208_2_42.csv
# Currently processing  208_2_43.csv
# Currently processing  208_2_44.csv
# Currently processing  208_2_45.csv
# Currently processing  208_2_46.csv
# Currently processing  208_2_47.csv
# Currently processing  208_2_5.csv
# Currently processing  208_2_6.csv
# Currently processing  208_2_7.csv
# Currently processing  208_2_8.csv
# Currently processing  208_2_9.csv
# Currently processing  209_1_0.csv
# Currently processing  209_1_1.csv
# Currently processing  209_1_10.csv
# Currently processing  209_1_11.csv
# Currently processing  209_1_12.csv
# Currently processing  209_1_13.csv
# Currently processing  209_1_14.csv
# Currently processing  209_1_15.csv
# Currently processing  209_1_16.csv
# Currently processing  209_1_17.csv
# Currently processing  209_1_18.csv
# Currently processing  209_1_19.csv
# Currently processing  209_1_2.csv
# Currently processing  209_1_20.csv
# Currently processing  209_1_21.csv
# Currently processing  209_1_22.csv
# Currently processing  209_1_23.csv
# Currently processing  209_1_24.csv
# Currently processing  209_1_25.csv
# Currently processing  209_1_26.csv
# Currently processing  209_1_27.csv
# Currently processing  209_1_28.csv
# Currently processing  209_1_29.csv
# Currently processing  209_1_3.csv
# Currently processing  209_1_30.csv
# Currently processing  209_1_31.csv
# Currently processing  209_1_32.csv
# Currently processing  209_1_33.csv
# Currently processing  209_1_34.csv
# Currently processing  209_1_35.csv
# Currently processing  209_1_36.csv
# Currently processing  209_1_37.csv
# Currently processing  209_1_38.csv
# Currently processing  209_1_39.csv
# Currently processing  209_1_4.csv
# Currently processing  209_1_40.csv
# Currently processing  209_1_41.csv
# Currently processing  209_1_42.csv
# Currently processing  209_1_43.csv
# Currently processing  209_1_44.csv
# Currently processing  209_1_45.csv
# Currently processing  209_1_46.csv
# Currently processing  209_1_47.csv
# Currently processing  209_1_48.csv
# Currently processing  209_1_49.csv
# Currently processing  209_1_5.csv
# Currently processing  209_1_50.csv
# Currently processing  209_1_51.csv
# Currently processing  209_1_52.csv
# Currently processing  209_1_53.csv
# Currently processing  209_1_54.csv
# Currently processing  209_1_55.csv
# Currently processing  209_1_56.csv
# Currently processing  209_1_6.csv
# Currently processing  209_1_7.csv
# Currently processing  209_1_8.csv
# Currently processing  209_1_9.csv
# Currently processing  209_2_0.csv
# Currently processing  209_2_1.csv
# Currently processing  209_2_10.csv
# Currently processing  209_2_11.csv
# Currently processing  209_2_12.csv
# Currently processing  209_2_13.csv
# Currently processing  209_2_14.csv
# Currently processing  209_2_15.csv
# Currently processing  209_2_16.csv
# Currently processing  209_2_17.csv
# Currently processing  209_2_18.csv
# Currently processing  209_2_19.csv
# Currently processing  209_2_20.csv
# Currently processing  209_2_21.csv
# Currently processing  209_2_22.csv
# Currently processing  209_2_23.csv
# Currently processing  209_2_24.csv
# Currently processing  209_2_25.csv
# Currently processing  209_2_26.csv
# Currently processing  209_2_27.csv
# Currently processing  209_2_28.csv
# Currently processing  209_2_29.csv
# Currently processing  209_2_3.csv
# Currently processing  209_2_30.csv
# Currently processing  209_2_31.csv
# Currently processing  209_2_32.csv
# Currently processing  209_2_33.csv
# Currently processing  209_2_34.csv
# Currently processing  209_2_35.csv
# Currently processing  209_2_36.csv
# Currently processing  209_2_37.csv
# Currently processing  209_2_38.csv
# Currently processing  209_2_39.csv
# Currently processing  209_2_4.csv
# Currently processing  209_2_40.csv
# Currently processing  209_2_41.csv
# Currently processing  209_2_42.csv
# Currently processing  209_2_43.csv
# Currently processing  209_2_44.csv
# Currently processing  209_2_5.csv
# Currently processing  209_2_6.csv
# Currently processing  209_2_7.csv
# Currently processing  209_2_8.csv
# Currently processing  209_2_9.csv
# Currently processing  210_1_0.csv
# Currently processing  210_1_10.csv
# Currently processing  210_1_11.csv
# Currently processing  210_1_12.csv
# Currently processing  210_1_13.csv
# Currently processing  210_1_14.csv
# Currently processing  210_1_15.csv
# Currently processing  210_1_16.csv
# Currently processing  210_1_17.csv
# Currently processing  210_1_18.csv
# Currently processing  210_1_19.csv
# Currently processing  210_1_2.csv
# Currently processing  210_1_20.csv
# Currently processing  210_1_21.csv
# Currently processing  210_1_22.csv
# Currently processing  210_1_23.csv
# Currently processing  210_1_24.csv
# Currently processing  210_1_25.csv
# Currently processing  210_1_26.csv
# Currently processing  210_1_27.csv
# Currently processing  210_1_28.csv
# Currently processing  210_1_29.csv
# Currently processing  210_1_3.csv
# Currently processing  210_1_30.csv
# Currently processing  210_1_31.csv
# Currently processing  210_1_32.csv
# Currently processing  210_1_33.csv
# Currently processing  210_1_34.csv
# Currently processing  210_1_35.csv
# Currently processing  210_1_36.csv
# Currently processing  210_1_37.csv
# Currently processing  210_1_38.csv
# Currently processing  210_1_39.csv
# Currently processing  210_1_4.csv
# Currently processing  210_1_40.csv
# Currently processing  210_1_41.csv
# Currently processing  210_1_42.csv
# Currently processing  210_1_43.csv
# Currently processing  210_1_44.csv
# Currently processing  210_1_45.csv
# Currently processing  210_1_46.csv
# Currently processing  210_1_47.csv
# Currently processing  210_1_48.csv
# Currently processing  210_1_49.csv
# Currently processing  210_1_5.csv
# Currently processing  210_1_50.csv
# Currently processing  210_1_51.csv
# Currently processing  210_1_52.csv
# Currently processing  210_1_53.csv
# Currently processing  210_1_54.csv
# Currently processing  210_1_55.csv
# Currently processing  210_1_56.csv
# Currently processing  210_1_57.csv
# Currently processing  210_1_6.csv
# Currently processing  210_1_7.csv
# Currently processing  210_1_8.csv
# Currently processing  210_1_9.csv
# Currently processing  210_2_0.csv
# Currently processing  210_2_1.csv
# Currently processing  210_2_10.csv
# Currently processing  210_2_11.csv
# Currently processing  210_2_12.csv
# Currently processing  210_2_13.csv
# Currently processing  210_2_14.csv
# Currently processing  210_2_15.csv
# Currently processing  210_2_16.csv
# Currently processing  210_2_17.csv
# Currently processing  210_2_18.csv
# Currently processing  210_2_19.csv
# Currently processing  210_2_2.csv
# Currently processing  210_2_20.csv
# Currently processing  210_2_21.csv
# Currently processing  210_2_22.csv
# Currently processing  210_2_23.csv
# Currently processing  210_2_24.csv
# Currently processing  210_2_25.csv
# Currently processing  210_2_26.csv
# Currently processing  210_2_27.csv
# Currently processing  210_2_28.csv
# Currently processing  210_2_29.csv
# Currently processing  210_2_3.csv
# Currently processing  210_2_30.csv
# Currently processing  210_2_31.csv
# Currently processing  210_2_32.csv
# Currently processing  210_2_33.csv
# Currently processing  210_2_34.csv
# Currently processing  210_2_35.csv
# Currently processing  210_2_36.csv
# Currently processing  210_2_37.csv
# Currently processing  210_2_38.csv
# Currently processing  210_2_39.csv
# Currently processing  210_2_4.csv
# Currently processing  210_2_40.csv
# Currently processing  210_2_41.csv
# Currently processing  210_2_42.csv
# Currently processing  210_2_43.csv
# Currently processing  210_2_44.csv
# Currently processing  210_2_45.csv
# Currently processing  210_2_46.csv
# Currently processing  210_2_47.csv
# Currently processing  210_2_48.csv
# Currently processing  210_2_49.csv
# Currently processing  210_2_5.csv
# Currently processing  210_2_50.csv
# Currently processing  210_2_51.csv
# Currently processing  210_2_52.csv
# Currently processing  210_2_53.csv
# Currently processing  210_2_54.csv
# Currently processing  210_2_55.csv
# Currently processing  210_2_56.csv
# Currently processing  210_2_57.csv
# Currently processing  210_2_6.csv
# Currently processing  210_2_7.csv
# Currently processing  210_2_8.csv
# Currently processing  210_2_9.csv
# Currently processing  211_1_0.csv
# Currently processing  211_1_1.csv
# Currently processing  211_1_10.csv
# Currently processing  211_1_11.csv
# Currently processing  211_1_12.csv
# Currently processing  211_1_13.csv
# Currently processing  211_1_14.csv
# Currently processing  211_1_15.csv
# Currently processing  211_1_16.csv
# Currently processing  211_1_17.csv
# Currently processing  211_1_18.csv
# Currently processing  211_1_19.csv
# Currently processing  211_1_2.csv
# Currently processing  211_1_20.csv
# Currently processing  211_1_21.csv
# Currently processing  211_1_22.csv
# Currently processing  211_1_23.csv
# Currently processing  211_1_24.csv
# Currently processing  211_1_25.csv
# Currently processing  211_1_26.csv
# Currently processing  211_1_27.csv
# Currently processing  211_1_28.csv
# Currently processing  211_1_29.csv
# Currently processing  211_1_3.csv
# Currently processing  211_1_30.csv
# Currently processing  211_1_31.csv
# Currently processing  211_1_32.csv
# Currently processing  211_1_33.csv
# Currently processing  211_1_34.csv
# Currently processing  211_1_35.csv
# Currently processing  211_1_36.csv
# Currently processing  211_1_37.csv
# Currently processing  211_1_38.csv
# Currently processing  211_1_39.csv
# Currently processing  211_1_4.csv
# Currently processing  211_1_40.csv
# Currently processing  211_1_41.csv
# Currently processing  211_1_42.csv
# Currently processing  211_1_43.csv
# Currently processing  211_1_44.csv
# Currently processing  211_1_45.csv
# Currently processing  211_1_46.csv
# Currently processing  211_1_47.csv
# Currently processing  211_1_48.csv
# Currently processing  211_1_49.csv
# Currently processing  211_1_5.csv
# Currently processing  211_1_50.csv
# Currently processing  211_1_51.csv
# Currently processing  211_1_52.csv
# Currently processing  211_1_53.csv
# Currently processing  211_1_6.csv
# Currently processing  211_1_7.csv
# Currently processing  211_1_8.csv
# Currently processing  211_1_9.csv
# Currently processing  211_2_0.csv
# Currently processing  211_2_1.csv
# Currently processing  211_2_10.csv
# Currently processing  211_2_11.csv
# Currently processing  211_2_12.csv
# Currently processing  211_2_13.csv
# Currently processing  211_2_14.csv
# Currently processing  211_2_15.csv
# Currently processing  211_2_16.csv
# Currently processing  211_2_17.csv
# Currently processing  211_2_18.csv
# Currently processing  211_2_19.csv
# Currently processing  211_2_2.csv
# Currently processing  211_2_20.csv
# Currently processing  211_2_21.csv
# Currently processing  211_2_22.csv
# Currently processing  211_2_23.csv
# Currently processing  211_2_24.csv
# Currently processing  211_2_25.csv
# Currently processing  211_2_26.csv
# Currently processing  211_2_27.csv
# Currently processing  211_2_28.csv
# Currently processing  211_2_29.csv
# Currently processing  211_2_3.csv
# Currently processing  211_2_30.csv
# Currently processing  211_2_31.csv
# Currently processing  211_2_32.csv
# Currently processing  211_2_33.csv
# Currently processing  211_2_34.csv
# Currently processing  211_2_35.csv
# Currently processing  211_2_36.csv
# Currently processing  211_2_37.csv
# Currently processing  211_2_38.csv
# Currently processing  211_2_39.csv
# Currently processing  211_2_4.csv
# Currently processing  211_2_40.csv
# Currently processing  211_2_41.csv
# Currently processing  211_2_42.csv
# Currently processing  211_2_43.csv
# Currently processing  211_2_44.csv
# Currently processing  211_2_45.csv
# Currently processing  211_2_46.csv
# Currently processing  211_2_47.csv
# Currently processing  211_2_5.csv
# Currently processing  211_2_6.csv
# Currently processing  211_2_7.csv
# Currently processing  211_2_8.csv
# Currently processing  211_2_9.csv
# Currently processing  214_1_0.csv
# Currently processing  214_1_1.csv
# Currently processing  214_1_10.csv
# Currently processing  214_1_11.csv
# Currently processing  214_1_12.csv
# Currently processing  214_1_13.csv
# Currently processing  214_1_14.csv
# Currently processing  214_1_15.csv
# Currently processing  214_1_16.csv
# Currently processing  214_1_17.csv
# Currently processing  214_1_18.csv
# Currently processing  214_1_19.csv
# Currently processing  214_1_2.csv
# Currently processing  214_1_20.csv
# Currently processing  214_1_21.csv
# Currently processing  214_1_22.csv
# Currently processing  214_1_23.csv
# Currently processing  214_1_24.csv
# Currently processing  214_1_25.csv
# Currently processing  214_1_26.csv
# Currently processing  214_1_27.csv
# Currently processing  214_1_28.csv
# Currently processing  214_1_29.csv
# Currently processing  214_1_3.csv
# Currently processing  214_1_30.csv
# Currently processing  214_1_31.csv
# Currently processing  214_1_32.csv
# Currently processing  214_1_33.csv
# Currently processing  214_1_34.csv
# Currently processing  214_1_35.csv
# Currently processing  214_1_36.csv
# Currently processing  214_1_37.csv
# Currently processing  214_1_38.csv
# Currently processing  214_1_39.csv
# Currently processing  214_1_4.csv
# Currently processing  214_1_40.csv
# Currently processing  214_1_41.csv
# Currently processing  214_1_42.csv
# Currently processing  214_1_43.csv
# Currently processing  214_1_44.csv
# Currently processing  214_1_45.csv
# Currently processing  214_1_46.csv
# Currently processing  214_1_47.csv
# Currently processing  214_1_48.csv
# Currently processing  214_1_49.csv
# Currently processing  214_1_5.csv
# Currently processing  214_1_50.csv
# Currently processing  214_1_51.csv
# Currently processing  214_1_52.csv
# Currently processing  214_1_53.csv
# Currently processing  214_1_54.csv
# Currently processing  214_1_55.csv
# Currently processing  214_1_56.csv
# Currently processing  214_1_57.csv
# Currently processing  214_1_58.csv
# Currently processing  214_1_59.csv
# Currently processing  214_1_6.csv
# Currently processing  214_1_60.csv
# Currently processing  214_1_61.csv
# Currently processing  214_1_62.csv
# Currently processing  214_1_63.csv
# Currently processing  214_1_7.csv
# Currently processing  214_1_8.csv
# Currently processing  214_1_9.csv
# Currently processing  214_2_0.csv
# Currently processing  214_2_1.csv
# Currently processing  214_2_10.csv
# Currently processing  214_2_11.csv
# Currently processing  214_2_12.csv
# Currently processing  214_2_13.csv
# Currently processing  214_2_14.csv
# Currently processing  214_2_15.csv
# Currently processing  214_2_16.csv
# Currently processing  214_2_17.csv
# Currently processing  214_2_18.csv
# Currently processing  214_2_19.csv
# Currently processing  214_2_2.csv
# Currently processing  214_2_20.csv
# Currently processing  214_2_21.csv
# Currently processing  214_2_22.csv
# Currently processing  214_2_23.csv
# Currently processing  214_2_24.csv
# Currently processing  214_2_25.csv
# Currently processing  214_2_26.csv
# Currently processing  214_2_27.csv
# Currently processing  214_2_28.csv
# Currently processing  214_2_29.csv
# Currently processing  214_2_3.csv
# Currently processing  214_2_30.csv
# Currently processing  214_2_31.csv
# Currently processing  214_2_32.csv
# Currently processing  214_2_33.csv
# Currently processing  214_2_34.csv
# Currently processing  214_2_35.csv
# Currently processing  214_2_36.csv
# Currently processing  214_2_37.csv
# Currently processing  214_2_38.csv
# Currently processing  214_2_39.csv
# Currently processing  214_2_4.csv
# Currently processing  214_2_40.csv
# Currently processing  214_2_41.csv
# Currently processing  214_2_42.csv
# Currently processing  214_2_43.csv
# Currently processing  214_2_44.csv
# Currently processing  214_2_45.csv
# Currently processing  214_2_46.csv
# Currently processing  214_2_47.csv
# Currently processing  214_2_48.csv
# Currently processing  214_2_49.csv
# Currently processing  214_2_5.csv
# Currently processing  214_2_50.csv
# Currently processing  214_2_51.csv
# Currently processing  214_2_52.csv
# Currently processing  214_2_53.csv
# Currently processing  214_2_54.csv
# Currently processing  214_2_55.csv
# Currently processing  214_2_56.csv
# Currently processing  214_2_57.csv
# Currently processing  214_2_58.csv
# Currently processing  214_2_59.csv
# Currently processing  214_2_6.csv
# Currently processing  214_2_60.csv
# Currently processing  214_2_61.csv
# Currently processing  214_2_7.csv
# Currently processing  214_2_8.csv
# Currently processing  214_2_9.csv
# Currently processing  215_1_0.csv
# Currently processing  215_1_1.csv
# Currently processing  215_1_10.csv
# Currently processing  215_1_11.csv
# Currently processing  215_1_12.csv
# Currently processing  215_1_13.csv
# Currently processing  215_1_14.csv
# Currently processing  215_1_15.csv
# Currently processing  215_1_16.csv
# Currently processing  215_1_17.csv
# Currently processing  215_1_18.csv
# Currently processing  215_1_19.csv
# Currently processing  215_1_2.csv
# Currently processing  215_1_20.csv
# Currently processing  215_1_21.csv
# Currently processing  215_1_22.csv
# Currently processing  215_1_23.csv
# Currently processing  215_1_24.csv
# Currently processing  215_1_25.csv
# Currently processing  215_1_26.csv
# Currently processing  215_1_27.csv
# Currently processing  215_1_28.csv
# Currently processing  215_1_29.csv
# Currently processing  215_1_3.csv
# Currently processing  215_1_30.csv
# Currently processing  215_1_31.csv
# Currently processing  215_1_32.csv
# Currently processing  215_1_33.csv
# Currently processing  215_1_34.csv
# Currently processing  215_1_35.csv
# Currently processing  215_1_36.csv
# Currently processing  215_1_37.csv
# Currently processing  215_1_38.csv
# Currently processing  215_1_39.csv
# Currently processing  215_1_4.csv
# Currently processing  215_1_40.csv
# Currently processing  215_1_41.csv
# Currently processing  215_1_42.csv
# Currently processing  215_1_43.csv
# Currently processing  215_1_44.csv
# Currently processing  215_1_45.csv
# Currently processing  215_1_46.csv
# Currently processing  215_1_47.csv
# Currently processing  215_1_48.csv
# Currently processing  215_1_49.csv
# Currently processing  215_1_5.csv
# Currently processing  215_1_50.csv
# Currently processing  215_1_51.csv
# Currently processing  215_1_52.csv
# Currently processing  215_1_53.csv
# Currently processing  215_1_54.csv
# Currently processing  215_1_6.csv
# Currently processing  215_1_7.csv
# Currently processing  215_1_8.csv
# Currently processing  215_1_9.csv
# Currently processing  215_2_0.csv
# Currently processing  215_2_1.csv
# Currently processing  215_2_10.csv
# Currently processing  215_2_11.csv
# ...
# Currently processing  313_1_22.csv
# Currently processing  313_1_23.csv
# Currently processing  313_1_24.csv
# Currently processing  313_1_25.csv
# Currently processing  313_1_26.csv
# Currently processing  313_1_27.csv
# Currently processing  313_1_28.csv
# Currently processing  313_1_29.csv
# Currently processing  313_1_30.csv
# Currently processing  313_1_31.csv
# Currently processing  313_1_32.csv
# Currently processing  313_1_33.csv
# Currently processing  313_1_34.csv
# Currently processing  313_1_35.csv
# Currently processing  313_1_36.csv
# Currently processing  313_1_4.csv
# Currently processing  313_1_5.csv
# Currently processing  313_1_6.csv
# Currently processing  313_1_7.csv
# Currently processing  313_1_8.csv
# Currently processing  313_1_9.csv
# Currently processing  313_2_0.csv
# Currently processing  313_2_1.csv
# Currently processing  313_2_10.csv
# Currently processing  313_2_11.csv
# Currently processing  313_2_12.csv
# Currently processing  313_2_13.csv
# Currently processing  313_2_14.csv
# Currently processing  313_2_15.csv
# Currently processing  313_2_16.csv
# Currently processing  313_2_17.csv
# Currently processing  313_2_18.csv
# Currently processing  313_2_19.csv
# Currently processing  313_2_2.csv
# Currently processing  313_2_20.csv
# Currently processing  313_2_21.csv
# Currently processing  313_2_22.csv
# Currently processing  313_2_24.csv
# Currently processing  313_2_25.csv
# Currently processing  313_2_26.csv
# Currently processing  313_2_27.csv
# Currently processing  313_2_28.csv
# Currently processing  313_2_29.csv
# Currently processing  313_2_3.csv
# Currently processing  313_2_30.csv
# Currently processing  313_2_31.csv
# Currently processing  313_2_32.csv
# Currently processing  313_2_33.csv
# Currently processing  313_2_34.csv
# Currently processing  313_2_35.csv
# Currently processing  313_2_36.csv
# Currently processing  313_2_37.csv
# Currently processing  313_2_38.csv
# Currently processing  313_2_39.csv
# Currently processing  313_2_4.csv
# Currently processing  313_2_5.csv
# Currently processing  313_2_6.csv
# Currently processing  313_2_7.csv
# Currently processing  313_2_8.csv
# Currently processing  313_2_9.csv
# Currently processing  314_1_0.csv
# Currently processing  314_1_1.csv
# Currently processing  314_1_10.csv
# Currently processing  314_1_11.csv
# Currently processing  314_1_12.csv
# Currently processing  314_1_13.csv
# Currently processing  314_1_14.csv
# Currently processing  314_1_15.csv
# Currently processing  314_1_16.csv
# Currently processing  314_1_17.csv
# Currently processing  314_1_18.csv
# Currently processing  314_1_19.csv
# Currently processing  314_1_2.csv
# Currently processing  314_1_20.csv
# Currently processing  314_1_21.csv
# Currently processing  314_1_22.csv
# Currently processing  314_1_23.csv
# Currently processing  314_1_24.csv
# Currently processing  314_1_25.csv
# Currently processing  314_1_26.csv
# Currently processing  314_1_27.csv
# Currently processing  314_1_28.csv
# Currently processing  314_1_29.csv
# Currently processing  314_1_3.csv
# Currently processing  314_1_30.csv
# Currently processing  314_1_31.csv
# Currently processing  314_1_4.csv
# Currently processing  314_1_5.csv
# Currently processing  314_1_6.csv
# Currently processing  314_1_8.csv
# Currently processing  314_1_9.csv
# Currently processing  314_2_0.csv
# Currently processing  314_2_1.csv
# Currently processing  314_2_11.csv
# Currently processing  314_2_13.csv
# Currently processing  314_2_14.csv
# Currently processing  314_2_15.csv
# Currently processing  314_2_16.csv
# Currently processing  314_2_17.csv
# Currently processing  314_2_18.csv
# Currently processing  314_2_19.csv
# Currently processing  314_2_2.csv
# Currently processing  314_2_20.csv
# Currently processing  314_2_3.csv
# Currently processing  314_2_4.csv
# Currently processing  314_2_5.csv
# Currently processing  314_2_7.csv
# Currently processing  314_2_8.csv
# Currently processing  314_2_9.csv
# Currently processing  318_1_0.csv
# Currently processing  318_1_1.csv
# Currently processing  318_1_10.csv
# Currently processing  318_1_11.csv
# Currently processing  318_1_12.csv
# Currently processing  318_1_2.csv
# Currently processing  318_1_3.csv
# Currently processing  318_1_4.csv
# Currently processing  318_1_5.csv
# Currently processing  318_1_6.csv
# Currently processing  318_1_7.csv
# Currently processing  318_1_8.csv
# Currently processing  318_2_0.csv
# Currently processing  318_2_1.csv
# Currently processing  318_2_10.csv
# Currently processing  318_2_11.csv
# Currently processing  318_2_12.csv
# Currently processing  318_2_14.csv
# Currently processing  318_2_2.csv
# Currently processing  318_2_3.csv
# Currently processing  318_2_4.csv
# Currently processing  318_2_5.csv
# Currently processing  318_2_6.csv
# Currently processing  318_2_7.csv
# Currently processing  318_2_8.csv
# Currently processing  318_2_9.csv
# Currently processing  320_1_0.csv
# Currently processing  320_1_1.csv
# Currently processing  320_1_10.csv
# Currently processing  320_1_11.csv
# Currently processing  320_1_12.csv
# Currently processing  320_1_13.csv
# Currently processing  320_1_14.csv
# Currently processing  320_1_15.csv
# Currently processing  320_1_16.csv
# Currently processing  320_1_17.csv
# Currently processing  320_1_18.csv
# Currently processing  320_1_19.csv
# Currently processing  320_1_2.csv
# Currently processing  320_1_20.csv
# Currently processing  320_1_21.csv
# Currently processing  320_1_22.csv
# Currently processing  320_1_23.csv
# Currently processing  320_1_24.csv
# Currently processing  320_1_25.csv
# Currently processing  320_1_26.csv
# Currently processing  320_1_27.csv
# Currently processing  320_1_28.csv
# Currently processing  320_1_29.csv
# Currently processing  320_1_3.csv
# Currently processing  320_1_30.csv
# Currently processing  320_1_31.csv
# Currently processing  320_1_32.csv
# Currently processing  320_1_33.csv
# Currently processing  320_1_34.csv
# Currently processing  320_1_35.csv
# Currently processing  320_1_36.csv
# Currently processing  320_1_37.csv
# Currently processing  320_1_38.csv
# Currently processing  320_1_39.csv
# Currently processing  320_1_4.csv
# Currently processing  320_1_40.csv
# Currently processing  320_1_41.csv
# Currently processing  320_1_42.csv
# Currently processing  320_1_5.csv
# Currently processing  320_1_6.csv
# Currently processing  320_1_7.csv
# Currently processing  320_1_8.csv
# Currently processing  320_2_0.csv
# Currently processing  320_2_1.csv
# Currently processing  320_2_10.csv
# Currently processing  320_2_11.csv
# Currently processing  320_2_12.csv
# Currently processing  320_2_13.csv
# Currently processing  320_2_14.csv
# Currently processing  320_2_15.csv
# Currently processing  320_2_16.csv
# Currently processing  320_2_17.csv
# Currently processing  320_2_18.csv
# Currently processing  320_2_19.csv
# Currently processing  320_2_2.csv
# Currently processing  320_2_20.csv
# Currently processing  320_2_21.csv
# Currently processing  320_2_22.csv
# Currently processing  320_2_23.csv
# Currently processing  320_2_24.csv
# Currently processing  320_2_25.csv
# Currently processing  320_2_26.csv
# Currently processing  320_2_27.csv
# Currently processing  320_2_28.csv
# Currently processing  320_2_29.csv
# Currently processing  320_2_3.csv
# Currently processing  320_2_30.csv
# Currently processing  320_2_31.csv
# Currently processing  320_2_32.csv
# Currently processing  320_2_33.csv
# Currently processing  320_2_34.csv
# Currently processing  320_2_35.csv
# Currently processing  320_2_36.csv
# Currently processing  320_2_37.csv
# Currently processing  320_2_38.csv
# Currently processing  320_2_39.csv
# Currently processing  320_2_4.csv
# Currently processing  320_2_40.csv
# Currently processing  320_2_41.csv
# Currently processing  320_2_42.csv
# Currently processing  320_2_43.csv
# Currently processing  320_2_44.csv
# Currently processing  320_2_45.csv
# Currently processing  320_2_46.csv
# Currently processing  320_2_47.csv
# Currently processing  320_2_48.csv
# Currently processing  320_2_49.csv
# Currently processing  320_2_5.csv
# Currently processing  320_2_6.csv
# Currently processing  320_2_7.csv
# Currently processing  320_2_8.csv
# Currently processing  320_2_9.csv
# Currently processing  321_1_0.csv
# Currently processing  321_1_1.csv
# Currently processing  321_1_10.csv
# Currently processing  321_1_11.csv
# Currently processing  321_1_12.csv
# Currently processing  321_1_13.csv
# Currently processing  321_1_14.csv
# Currently processing  321_1_15.csv
# Currently processing  321_1_16.csv
# Currently processing  321_1_17.csv
# Currently processing  321_1_18.csv
# Currently processing  321_1_19.csv
# Currently processing  321_1_2.csv
# Currently processing  321_1_20.csv
# Currently processing  321_1_22.csv
# Currently processing  321_1_24.csv
# Currently processing  321_1_25.csv
# Currently processing  321_1_26.csv
# Currently processing  321_1_27.csv
# Currently processing  321_1_28.csv
# Currently processing  321_1_29.csv
# Currently processing  321_1_3.csv
# Currently processing  321_1_30.csv
# Currently processing  321_1_31.csv
# Currently processing  321_1_32.csv
# Currently processing  321_1_33.csv
# Currently processing  321_1_34.csv
# Currently processing  321_1_35.csv
# Currently processing  321_1_36.csv
# Currently processing  321_1_37.csv
# Currently processing  321_1_38.csv
# Currently processing  321_1_39.csv
# Currently processing  321_1_4.csv
# Currently processing  321_1_5.csv
# Currently processing  321_1_6.csv
# Currently processing  321_1_7.csv
# Currently processing  321_1_8.csv
# Currently processing  321_1_9.csv
# Currently processing  321_2_0.csv
# Currently processing  321_2_1.csv
# Currently processing  321_2_10.csv
# Currently processing  321_2_11.csv
# Currently processing  321_2_12.csv
# Currently processing  321_2_14.csv
# Currently processing  321_2_16.csv
# Currently processing  321_2_17.csv
# Currently processing  321_2_18.csv
# Currently processing  321_2_19.csv
# Currently processing  321_2_2.csv
# Currently processing  321_2_20.csv
# Currently processing  321_2_21.csv
# Currently processing  321_2_3.csv
# Currently processing  321_2_4.csv
# Currently processing  321_2_5.csv
# Currently processing  321_2_6.csv
# Currently processing  321_2_7.csv
# Currently processing  321_2_9.csv
# Currently processing  322_1_1.csv
# Currently processing  322_1_10.csv
# Currently processing  322_1_11.csv
# Currently processing  322_1_12.csv
# Currently processing  322_1_13.csv
# Currently processing  322_1_14.csv
# Currently processing  322_1_15.csv
# Currently processing  322_1_16.csv
# Currently processing  322_1_17.csv
# Currently processing  322_1_18.csv
# Currently processing  322_1_19.csv
# Currently processing  322_1_2.csv
# Currently processing  322_1_20.csv
# Currently processing  322_1_21.csv
# Currently processing  322_1_22.csv
# Currently processing  322_1_23.csv
# Currently processing  322_1_24.csv
# Currently processing  322_1_25.csv
# Currently processing  322_1_26.csv
# Currently processing  322_1_27.csv
# Currently processing  322_1_28.csv
# Currently processing  322_1_29.csv
# Currently processing  322_1_3.csv
# Currently processing  322_1_30.csv
# Currently processing  322_1_31.csv
# Currently processing  322_1_32.csv
# Currently processing  322_1_33.csv
# Currently processing  322_1_34.csv
# Currently processing  322_1_35.csv
# Currently processing  322_1_36.csv
# Currently processing  322_1_37.csv
# Currently processing  322_1_4.csv
# Currently processing  322_1_5.csv
# Currently processing  322_1_6.csv
# Currently processing  322_1_7.csv
# Currently processing  322_1_8.csv
# Currently processing  322_1_9.csv
# Currently processing  322_2_0.csv
# Currently processing  322_2_1.csv
# Currently processing  322_2_10.csv
# Currently processing  322_2_11.csv
# Currently processing  322_2_12.csv
# Currently processing  322_2_13.csv
# Currently processing  322_2_14.csv
# Currently processing  322_2_15.csv
# Currently processing  322_2_16.csv
# Currently processing  322_2_17.csv
# Currently processing  322_2_18.csv
# Currently processing  322_2_19.csv
# Currently processing  322_2_2.csv
# Currently processing  322_2_3.csv
# Currently processing  322_2_4.csv
# Currently processing  322_2_5.csv
# Currently processing  322_2_6.csv
# Currently processing  322_2_7.csv
# Currently processing  322_2_8.csv
# Currently processing  322_2_9.csv
# Currently processing  323_1_0.csv
# Currently processing  323_1_1.csv
# Currently processing  323_1_10.csv
# Currently processing  323_1_11.csv
# Currently processing  323_1_12.csv
# Currently processing  323_1_13.csv
# Currently processing  323_1_14.csv
# Currently processing  323_1_15.csv
# Currently processing  323_1_16.csv
# Currently processing  323_1_17.csv
# Currently processing  323_1_18.csv
# Currently processing  323_1_19.csv
# Currently processing  323_1_2.csv
# Currently processing  323_1_20.csv
# Currently processing  323_1_21.csv
# Currently processing  323_1_22.csv
# Currently processing  323_1_23.csv
# Currently processing  323_1_24.csv
# Currently processing  323_1_25.csv
# Currently processing  323_1_26.csv
# Currently processing  323_1_27.csv
# Currently processing  323_1_28.csv
# Currently processing  323_1_29.csv
# Currently processing  323_1_3.csv
# Currently processing  323_1_30.csv
# Currently processing  323_1_31.csv
# Currently processing  323_1_32.csv
# Currently processing  323_1_33.csv
# Currently processing  323_1_34.csv
# Currently processing  323_1_35.csv
# Currently processing  323_1_36.csv
# Currently processing  323_1_37.csv
# Currently processing  323_1_38.csv
# Currently processing  323_1_39.csv
# Currently processing  323_1_4.csv
# Currently processing  323_1_40.csv
# Currently processing  323_1_41.csv
# Currently processing  323_1_42.csv
# Currently processing  323_1_43.csv
# Currently processing  323_1_44.csv
# Currently processing  323_1_45.csv
# Currently processing  323_1_46.csv
# Currently processing  323_1_47.csv
# Currently processing  323_1_48.csv
# Currently processing  323_1_49.csv
# Currently processing  323_1_5.csv
# Currently processing  323_1_50.csv
# Currently processing  323_1_51.csv
# Currently processing  323_1_52.csv
# Currently processing  323_1_53.csv
# Currently processing  323_1_54.csv
# Currently processing  323_1_55.csv
# Currently processing  323_1_56.csv
# Currently processing  323_1_57.csv
# Currently processing  323_1_58.csv
# Currently processing  323_1_59.csv
# Currently processing  323_1_6.csv
# Currently processing  323_1_60.csv
# Currently processing  323_1_61.csv
# Currently processing  323_1_7.csv
# Currently processing  323_1_8.csv
# Currently processing  323_1_9.csv
# Currently processing  323_2_0.csv
# Currently processing  323_2_1.csv
# Currently processing  323_2_10.csv
# Currently processing  323_2_11.csv
# Currently processing  323_2_12.csv
# Currently processing  323_2_13.csv
# Currently processing  323_2_14.csv
# Currently processing  323_2_15.csv
# Currently processing  323_2_16.csv
# Currently processing  323_2_17.csv
# Currently processing  323_2_18.csv
# Currently processing  323_2_19.csv
# Currently processing  323_2_2.csv
# Currently processing  323_2_20.csv
# Currently processing  323_2_21.csv
# Currently processing  323_2_22.csv
# Currently processing  323_2_23.csv
# Currently processing  323_2_24.csv
# Currently processing  323_2_25.csv
# Currently processing  323_2_26.csv
# Currently processing  323_2_27.csv
# Currently processing  323_2_28.csv
# Currently processing  323_2_29.csv
# Currently processing  323_2_3.csv
# Currently processing  323_2_30.csv
# Currently processing  323_2_31.csv
# Currently processing  323_2_32.csv
# Currently processing  323_2_33.csv
# Currently processing  323_2_34.csv
# Currently processing  323_2_35.csv
# Currently processing  323_2_36.csv
# Currently processing  323_2_37.csv
# Currently processing  323_2_38.csv
# Currently processing  323_2_39.csv
# Currently processing  323_2_4.csv
# Currently processing  323_2_40.csv
# Currently processing  323_2_41.csv
# Currently processing  323_2_42.csv
# Currently processing  323_2_43.csv
# Currently processing  323_2_44.csv
# Currently processing  323_2_45.csv
# Currently processing  323_2_46.csv
# Currently processing  323_2_47.csv
# Currently processing  323_2_48.csv
# Currently processing  323_2_49.csv
# Currently processing  323_2_5.csv
# Currently processing  323_2_50.csv
# Currently processing  323_2_51.csv
# Currently processing  323_2_52.csv
# Currently processing  323_2_53.csv
# Currently processing  323_2_54.csv
# Currently processing  323_2_55.csv
# Currently processing  323_2_56.csv
# Currently processing  323_2_6.csv
# Currently processing  323_2_7.csv
# Currently processing  323_2_8.csv
# Currently processing  323_2_9.csv

# %% [markdown]
# ### Creating the grouped 5 strides from the downsampled strides, such that we have 5x30 = 150 time steps and 4 features per each grouped stride for multi-stride analysis on raw treadmill features
# * Make sure to not mix trials or PIDs when creating the grouped strides
# * We only create grouped strides if the 5 strides were consequetive
# * The gait domain knowledge features have 1437 sequences of 5 strides each

# %%
downsampled_labels = pd.read_csv(path_to_save_downsampled_strides + '..\\downsampled_stride_raw_labels.csv', index_col = 0)
downsampled_labels['PID'] = downsampled_labels['PID'].astype(int)
downsampled_labels['TrialID'] = downsampled_labels['TrialID'].astype(int)

# %%
path_to_save_grouped_strides = 'C:\\Users\\Rachneet Kaur\\Box\\GaitLSTMproject\\raw_treadmill_features\\grouped_5strides\\'

#Keeping 5 strides per group
strides_per_sequence = 5
#Skipping 2 strides for making the next group of 5 strides 
skippedSteps = 2

#Dataframe to keep track of all the grouped strides
grouped_labels = pd.DataFrame(columns = ['PID', 'TrialID', 'GroupIndex', 'FileName', 'label', 'StridesInThisGroup'])

# %%
PIDs = downsampled_labels.PID.unique()
trials = downsampled_labels.TrialID.unique()
for PID in PIDs:
    if PID<300:
        label = 0
    else:
        label = 1
    for trial in trials:
        print ('Processing PID ', PID, ' and trial ', trial)
        snip = downsampled_labels[(downsampled_labels.PID == PID) & (downsampled_labels.TrialID ==trial)]
        index = 0
        group_index = 0
        while (index<=(len(snip)-strides_per_sequence)):
            filenames = []
            snippet = snip[index: index+strides_per_sequence]['FileName']
            snippet_nan = snippet.isna().sum()
            if (snippet_nan==0):
                for idx, filename in enumerate(snippet):
                    filenames.append(filename)
                    if idx ==0:
                        temp = pd.read_csv(path_to_save_downsampled_strides+filename, index_col = 0)
                    else:
                        temp = pd.concat((temp, pd.read_csv(path_to_save_downsampled_strides+filename, index_col = 0)), ignore_index=True)
                grouped_filename = str(PID)+ '_' + str(trial) + '_' + str(group_index) + '.csv'
                temp.to_csv(path_to_save_grouped_strides + grouped_filename) 
                grouped_labels.loc[len(grouped_labels)] = [PID, trial, group_index, grouped_filename, label, filenames]
                index+=skippedSteps
                group_index+=1  
            else:
                print ('This is a NaN/inconsequetive strides group')
                index+=skippedSteps
grouped_labels.to_csv(path_to_save_grouped_strides + '..\\grouped_labels.csv')
# Out:
# Processing PID  200  and trial  1
# Processing PID  200  and trial  2
# Processing PID  201  and trial  1
# Processing PID  201  and trial  2
# This is a NaN/inconsequetive strides group
# This is a NaN/inconsequetive strides group
# Processing PID  202  and trial  1
# Processing PID  202  and trial  2
# Processing PID  203  and trial  1
# This is a NaN/inconsequetive strides group
# This is a NaN/inconsequetive strides group
# This is a NaN/inconsequetive strides group
# Processing PID  203  and trial  2
# Processing PID  204  and trial  1
# This is a NaN/inconsequetive strides group
# Processing PID  204  and trial  2
# Processing PID  205  and trial  1
# This is a NaN/inconsequetive strides group
# Processing PID  205  and trial  2
# Processing PID  206  and trial  1
# Processing PID  206  and trial  2
# Processing PID  207  and trial  1
# Processing PID  207  and trial  2
# Processing PID  208  and trial  1
# Processing PID  208  and trial  2
# Processing PID  209  and trial  1
# Processing PID  209  and trial  2
# This is a NaN/inconsequetive strides group
# This is a NaN/inconsequetive strides group
# Processing PID  210  and trial  1
# This is a NaN/inconsequetive strides group
# Processing PID  210  and trial  2
# Processing PID  211  and trial  1
# Processing PID  211  and trial  2
# Processing PID  214  and trial  1
# Processing PID  214  and trial  2
# Processing PID  215  and trial  1
# Processing PID  215  and trial  2
# Processing PID  216  and trial  1
# Processing PID  216  and trial  2
# This is a NaN/inconsequetive strides group
# Processing PID  217  and trial  1
# Processing PID  217  and trial  2
# Processing PID  218  and trial  1
# Processing PID  218  and trial  2
# Processing PID  219  and trial  1
# Processing PID  219  and trial  2
# Processing PID  300  and trial  1
# Processing PID  300  and trial  2
# Processing PID  301  and trial  1
# Processing PID  301  and trial  2
# Processing PID  302  and trial  1
# Processing PID  302  and trial  2
# Processing PID  303  and trial  1
# Processing PID  303  and trial  2
# Processing PID  304  and trial  1
# Processing PID  304  and trial  2
# Processing PID  305  and trial  1
# Processing PID  305  and trial  2
# Processing PID  306  and trial  1
# Processing PID  306  and trial  2
# Processing PID  307  and trial  1
# Processing PID  307  and trial  2
# Processing PID  308  and trial  1
# Processing PID  308  and trial  2
# Processing PID  312  and trial  1
# Processing PID  312  and trial  2
# Processing PID  313  and trial  1
# This is a NaN/inconsequetive strides group
# This is a NaN/inconsequetive strides group
# Processing PID  313  and trial  2
# This is a NaN/inconsequetive strides group
# This is a NaN/inconsequetive strides group
# Processing PID  314  and trial  1
# This is a NaN/inconsequetive strides group
# This is a NaN/inconsequetive strides group
# Processing PID  314  and trial  2
# This is a NaN/inconsequetive strides group
# This is a NaN/inconsequetive strides group
# This is a NaN/inconsequetive strides group
# This is a NaN/inconsequetive strides group
# This is a NaN/inconsequetive strides group
# This is a NaN/inconsequetive strides group
# Processing PID  318  and trial  1
# This is a NaN/inconsequetive strides group
# This is a NaN/inconsequetive strides group
# Processing PID  318  and trial  2
# This is a NaN/inconsequetive strides group
# Processing PID  320  and trial  1
# This is a NaN/inconsequetive strides group
# This is a NaN/inconsequetive strides group
# Processing PID  320  and trial  2
# Processing PID  321  and trial  1
# This is a NaN/inconsequetive strides group
# This is a NaN/inconsequetive strides group
# This is a NaN/inconsequetive strides group
# Processing PID  321  and trial  2
# This is a NaN/inconsequetive strides group
# This is a NaN/inconsequetive strides group
# This is a NaN/inconsequetive strides group
# This is a NaN/inconsequetive strides group
# This is a NaN/inconsequetive strides group
# This is a NaN/inconsequetive strides group
# Processing PID  322  and trial  1
# This is a NaN/inconsequetive strides group
# Processing PID  322  and trial  2
# Processing PID  323  and trial  1
# Processing PID  323  and trial  2

# %%
print (len(grouped_labels))
